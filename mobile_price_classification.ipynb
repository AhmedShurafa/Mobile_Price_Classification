# %% [markdown]
# <a href="https://colab.research.google.com/github/AhmedShurafa/Mobile_Price_Classification/blob/main/mobile_price_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
dataset = pd.read_csv('/content/train.csv')
dataset.head()
train_dataset = dataset.sample(frac=0.8,random_state=0)
test_dataset = dataset.drop(train_dataset.index)
sns.pairplot(train_dataset[["battery_power", "blue","dual_sim","four_g","int_memory","ram","talk_time","wifi","price_range"]], diag_kind="kde")
train_stats = train_dataset.describe()
train_stats = train_stats.transpose()
train_stats
# Out:
#                 count         mean          std    min       25%     50%  \
# battery_power  1600.0  1236.876250   441.779643  501.0   843.000  1225.0
# blue           1600.0     0.497500     0.500150    0.0     0.000     0.0
# clock_speed    1600.0     1.516000     0.822065    0.5     0.675     1.5
# dual_sim       1600.0     0.511250     0.500030    0.0     0.000     1.0
# fc             1600.0     4.355625     4.401564    0.0     1.000     3.0
# four_g         1600.0     0.520625     0.499731    0.0     0.000     1.0
# int_memory     1600.0    32.024375    18.183211    2.0    16.000    32.0
# m_dep          1600.0     0.500688     0.288826    0.1     0.200     0.5
# mobile_wt      1600.0   140.238125    35.586854   80.0   109.000   139.0
# n_cores        1600.0     4.506250     2.291996    1.0     3.000     4.0
# pc             1600.0     9.885625     6.046933    0.0     4.750    10.0
# px_height      1600.0   653.662500   445.655324    0.0   292.500   575.0
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

dataset = pd.read_csv('/content/train.csv')

train_dataset = dataset.sample(frac=0.8, random_state=0)
test_dataset = dataset.drop(train_dataset.index)

x = train_dataset['touch_screen']
y = train_dataset['price_range']

plt.xlabel('touch_screen')

plt.ylabel('price_range')

plt.title('Line Plots')

plt.bar( x, y )
# Out:
# <BarContainer object of 1600 artists>
